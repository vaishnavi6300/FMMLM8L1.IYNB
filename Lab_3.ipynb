# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi6300/FMMLM8L1.IYNB/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-13 12:28:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   114MB/s    in 0.6s
#
# 2025-04-13 12:28:13 (114 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30699  1801.00708v2  Understanding the surrounding environment of t...    cs
# 22187  1507.01059v2  Kernel Bayes' rule has been proposed as a nonp...  stat
# 6877   1707.00783v2  This paper introduces a simple and efficient d...    cs
# 37736  1802.04987v2  The problem of rating the performance of socce...  stat
# 1630   1702.01991v3  We present a visually grounded model of speech...    cs
# ...             ...                                                ...   ...
# 12921  1711.05825v2  Approximate Bayesian computation (ABC) and syn...  stat
# 16859  1706.09254v2  This paper describes the E2E data, a new datas...    cs
# 34164  1503.01258v1  This article addresses the question of the rel...    cs
# 25038  1504.02789v2  Advanced Driver Assistance Systems (ADAS) have...    cs
# 8272   1501.04717v1  Developing a reliable and practical face recog...    cs
#
#                                                    title  year  \
# 30699  Restricted Deformable Convolution based Road S...  2018
# 22187                      Remarks on kernel Bayes' rule  2015
# 6877   A simple efficient density estimator that enab...  2017
# 37736  PlayeRank: Multi-dimensional and role-aware ra...  2018
# 1630   Representations of language in a model of visu...  2017
# ...                                                  ...   ...
# 12921                  Bootstrapped synthetic likelihood  2017
# 16859  The E2E Dataset: New Challenges For End-to-End...  2017
# 34164  The concept "altruism" for sociological resear...  2015
# 25038  Car that Knows Before You Do: Anticipating Man...  2015
# 8272   Robust Face Recognition by Constrained Part-ba...  2015
#
#                                                 keywords
# 30699  [understanding, surrounding, environment, chal...
# 22187  [nonparametric, inference, reproducing, demons...
# 6877   [introduces, efficient, estimator, systematic,...
# 37736  [performance, attracting, companies, scientifi...
# 1630   [perception, utterances, recurrent, linguistic...
# ...                                                  ...
# 12921  [approximate, computation, synthetic, likeliho...
# 16859  [describes, generation, restaurant, frequently...
# 34164  [addresses, conceptualization, guillemotleftal...
# 25038  [assistance, conditions, dangerous, accidents,...
# 8272   [developing, practical, recognition, literatur...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30699    [understanding, surrounding, environment, chal...
# 22187    [nonparametric, inference, reproducing, demons...
# 6877     [introduces, efficient, estimator, systematic,...
# 37736    [performance, attracting, companies, scientifi...
# 1630     [perception, utterances, recurrent, linguistic...
#                                ...
# 12533    [asynchronous, distributed, solutions, effecti...
# 35750    [addresses, distributions, constraints, partic...
# 22956    [estimation, treatment, considerable, precisio...
# 4217     [fundamental, component, processes, developmen...
# 22900    [considers, classification, connectome, connec...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8708 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="26290e8c-1129-4471-9bee-f2d0980d88cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26290e8c-1129-4471-9bee-f2d0980d88cb")) {                    Plotly.newPlot(                        "26290e8c-1129-4471-9bee-f2d0980d88cb",                        [{"x":["addresses","convolution","transformations","convolutional","environment","performance","production","conditioned","understanding","geometric","augmentation","segmentation","distortion","effectively","deformable","challenges","conventional","combining","effectiveness","demonstrate","architecture","transform","restricted","transformed","distortions","experiments","surrounding","autonomous","inference","theoretically","assumptions","experimentally","unnatural","nonparametric","phenomenon","reproducing","prediction","estimator","otherwise","advantage","assessments","discovers","impossible","expensive","replacing","computationally","magnitude","introduces","dimensions","thousands","systematic","efficient","subspaces","attracting","introducing","community","analytics","approaches","companies","availability","available","evaluation","capturing","generated","scientific","flexibility","pertaining","validation","improving","prominent","dimensional","experimental","principled","efficiency","significantly","application","searching","implement","framework","different","knowledge","representations","initially","utterances","linguistic","recurrent","perception","components","hierarchy","identification","processing","variability","similarity","achieving","broadcast","dissimilarities","challenge","successfully","broadcasts","recognition","mismatches","submissions","essential","distinguishing","conditional","generalize","independence","factorization","definitions","epistemic","possibility","valuation","probability","axiomatic","uncertainty","representing","corresponding","operation","background","operators","implementation","detection","effective","intensity","performed","foundations","extracted","conventionally","remaining","disentangled","importance","exploration","autoencoders","procedure","variational","qualitative","objective","interpretable","partially","typically","quantitative","discriminative","relatively","probabilistic","graphical","interested","architectures","structure","frameworks","specified","generative","approximated","supervised","variables","generalise","employing","properties","constructs","potential","projection","automatically","reconstruction","construction","automated","relationship","algorithm","constructing","interfaces","reproduce","conjunction","difficult","hypothesize","representation","observable","maintaining","consistency","regression","nonlinearity","conditions","incorporating","functions","predicting","decomposing","extension","statistic","estimation","formulation","decomposition","convergence","considerably","theoretical","benchmark","confidence","including","structural","differences","parameters","confident","hyperparameters","calculation"],"y":[47,48,31,391,119,881,26,20,148,65,13,230,18,118,12,118,113,103,186,495,235,61,56,23,9,626,17,51,197,34,60,54,1,25,25,12,225,33,15,89,13,9,13,65,17,94,65,93,54,34,35,411,20,1,47,69,15,424,9,20,292,230,61,163,45,37,7,48,125,14,203,363,18,160,282,266,19,63,491,796,325,255,14,14,68,142,47,103,34,117,281,36,139,73,6,2,144,93,2,399,2,3,73,18,102,54,34,30,21,11,32,2,190,6,88,77,115,48,78,53,137,342,246,29,136,12,131,4,19,3,86,56,19,115,55,46,155,39,58,121,60,96,63,168,68,24,123,362,35,31,102,21,204,127,4,40,205,12,157,48,192,91,69,90,66,830,35,16,6,20,134,5,393,31,41,71,120,8,145,54,207,87,7,73,7,218,87,71,120,20,135,220,50,287,78,60,280,5,15,16],"type":"bar"},{"x":["addresses","convolution","transformations","conv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7866666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Overcoming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Catastrophic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forgetting</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6224066390041494);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Selective</span> <span style=''>Network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Augmentation</span> <br/><br/><span style=''>Lifelong</span> <span style=''>learning</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>new</span> <span style=''>tasks</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>previous</span> <span style=''>tasks</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>for</span> <span style=''>example</span> <span style=''>to</span> <span style=''>prevent</span> <span style=''>accident</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.7288135593220338);'>autonomous</span> <span style=''>vehicles</span> <span style=''>by</span> <span style=''>applying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3626834381551362);'>knowledge</span> <span style=''>learned</span> <span style=''>on</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overcomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>catastrophic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forgetting</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>new</span> <span style=''>tasks</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.43999999999999995);'>preserves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>old</span> <span style=''>tasks</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>accessing</span> <span style=''>the</span> <span style=''>data</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>model</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>selective</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmentation</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.6224066390041494);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>experiment</span> <span style=''>results</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>in</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Semiparametric</span> <span style=''>Inverse</span> <span style=''>Dynamics</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style=''>inverse</span> <span style=''>dynamics</span> <span style=''>learning</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parametric</span> <span style=''>modeling</span> <span style=''>based</span> <span style=''>on</span> <span style=''>rigid</span> <span style=''>body</span> <span style=''>dynamics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>modeling</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>no</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>This</span> <span style=''>yields</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style=''>approach</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>of</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>models</span> <span style=''>We</span> <span style=''>validate</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>one</span> <span style=''>arm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>iCub</span> <span style=''>humanoid</span> <span style=''>robot</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.30240549828178687);'>dimensional</span> <span style=''>dataset</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>MapReduce</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058822);'>describes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>MapReduce</span> <span style='background-color:rgba(0, 255, 0, 0.3173076923076922);'>implementation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>minimum</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>Redundancy</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relevance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>method</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bioinformatics</span> <span style=''>and</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3287904599659286);'>inference</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>handles</span> <span style=''>both</span> <span style=''>tallnarrow</span> <span style=''>and</span> <span style=''>wideshort</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>further</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3173076923076922);'>implementation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>HadoopSpark</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scalability</span> <span style=''>on</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>millions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.41739130434782606);'>observations</span> <span style=''>or</span> <span style=''>features</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Environments</span> <span style=''>in</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>Dex</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>toolkit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specialized</span> <span style=''>for</span> <span style=''>training</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continual</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style=''>the</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continual</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>is</span> <span style=''>solved</span> <span style=''>using</span> <span style=''>optimal</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialization</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>first</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>easier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>produce</span> <span style=''>vastly</span> <span style=''>superior</span> <span style=''>results</span> <span style=''>than</span> <span style=''>standard</span> <span style=''>methods</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>baseline</span> <span style=''>method</span> <span style=''>across</span> <span style=''>ten</span> <span style=''>Dex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>We</span> <span style=''>finally</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>saliency</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style=''>analysis</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>shows</span> <span style=''>the</span> <span style=''>impact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>on</span> <span style=''>netwo ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	translation (0.04556871187656979)
# 	knowledge (0.11661284535342663)
# 	architecture (0.0843200574094008)
# 	representation (0.14101184068891282)
# 	segmentation (0.08252601363473269)
# 	information (0.25044851094366705)
# 	detection (0.12271259418729817)
# 	convolutional (0.14029422317904558)
# 	different (0.28561176892716184)
# 	recognition (0.14316469321851452)
#
# Some Statistics words are:
# 	algorithm (0.38152011922503726)
# 	stochastic (0.12667660208643816)
# 	estimation (0.16890213611525087)
# 	statistical (0.15300546448087432)
# 	distribution (0.17685047193243913)
# 	variables (0.14555389965226032)
# 	theoretical (0.16194734227521113)
# 	dimensional (0.18827620466964728)
# 	inference (0.19374068554396423)
# 	regression (0.18529557873820168)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eeac2cff-d246-4409-a7f3-187948d601e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeac2cff-d246-4409-a7f3-187948d601e2")) {                    Plotly.newPlot(                        "eeac2cff-d246-4409-a7f3-187948d601e2",                        [{"x":["addresses","convolution","transformations","convolutional","environment","performance","production","conditioned","understanding","geometric","augmentation","segmentation","distortion","effectively","deformable","challenges","conventional","combining","effectiveness","demonstrate","architecture","transform","restricted","transformed","distortions","experiments","surrounding","autonomous","inference","theoretically","assumptions","experimentally","unnatural","nonparametric","phenomenon","reproducing","prediction","estimator","otherwise","advantage","assessments","discovers","impossible","expensive","replacing","computationally","magnitude","introduces","dimensions","thousands","systematic","efficient","subspaces","attracting","introducing","community","analytics","approaches","companies","availability","available","evaluation","capturing","generated","scientific","flexibility","pertaining","validation","improving","prominent","dimensional","experimental","principled","efficiency","significantly","application","searching","implement","framework","different","knowledge","representations","initially","utterances","linguistic","recurrent","perception","components","hierarchy","identification","processing","variability","similarity","achieving","broadcast","dissimilarities","challenge","successfully","broadcasts","recognition","mismatches","submissions","essential","distinguishing","conditional","generalize","independence","factorization","definitions","epistemic","possibility","valuation","probability","axiomatic","uncertainty","representing","corresponding","operation","background","operators","implementation","detection","effective","intensity","performed","foundations","extracted","conventionally","remaining","disentangled","importance","exploration","autoencoders","procedure","variational","qualitative","objective","interpretable","partially","typically","quantitative","discriminative","relatively","probabilistic","graphical","interested","architectures","structure","frameworks","specified","generative","approximated","supervised","variables","generalise","employing","properties","constructs","potential","projection","automatically","reconstruction","construction","automated","relationship","algorithm","constructing","interfaces","reproduce","conjunction","difficult","hypothesize","representation","observable","maintaining","consistency","regression","nonlinearity","conditions","incorporating","functions","predicting","decomposing","extension","statistic","estimation","formulation","decomposition","convergence","considerably","theoretical","benchmark","confidence","including","structural","differences","parameters","confident","hyperparameters","calculation","underlying","simulations","likelihood","computing","deterministic","continuous","complexity","improvement","empirically","emphasizes","optimization","engineering","imperfect","cooperative","information","reinforcement","adversarial","behaviours","behavioural","traditional","principles","regarding","personality","psychological","personalities","economics","clustering","comprehensive","individuals","potentially","important","techniques","applications","complicated","psychology","consideration","following","experimenter","coefficients","introduce","screening","asymptotic","biological","successive","superiority","predictor","predictive","subsequently","dimension","popularly","implements","literature","correlation","m ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	experimenter
# 	eigendecomposition
# 	hyperpriors
# 	unbalancedness
# 	parameterizes
# 	contextually
# 	subpopulation
# 	autoimmune
# 	scleroderma
# 	subpopulations
# 	symmetrization
# 	penalizations
# 	covariates
# 	coherently
# 	dendrogram
# 	diagonalise
# 	delineates
# 	individualized
# 	heteroscedastic
# 	subsample
# Some words which never appear in Statistics papers:
# 	deformable
# 	broadcasts
# 	mismatches
# 	valuation
# 	conventionally
# 	emphasizes
# 	cooperative
# 	personalities
# 	psychology
# 	propositional
# 	skeletons
# 	provisioning
# 	continues
# 	steerable
# 	convincing
# 	referring
# 	proposition
# 	dempsters
# 	photometric
# 	reprojection

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0809994762300896e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.745
